# %% [markdown]
# <a href="https://colab.research.google.com/github/jr2ngb2/Object_Detection/blob/master/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/miranthajayatilake/YOLOw-Keras.git
# Out:
# Cloning into 'YOLOw-Keras'...
# remote: Enumerating objects: 60, done.
# remote: Total 60 (delta 0), reused 0 (delta 0), pack-reused 60
# Unpacking objects: 100% (60/60), done.

# %%
cd /content/YOLOw-Keras
# Out:
# /content/YOLOw-Keras

# %%
pwd
# Out:
# '/content/YOLOw-Keras'

# %%
cd /content
# Out:
# /content

# %%
# !wget https://github.com/qqwweee/keras-yolo3/blob/master/yolov3.cfg
# Out:
# --2018-11-13 04:12:49--  https://github.com/qqwweee/keras-yolo3/blob/master/yolov3.cfg
# Resolving github.com (github.com)... 192.30.255.112, 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘yolov3.cfg’
#
# yolov3.cfg              [ <=>                ] 206.96K  --.-KB/s    in 0.1s
#
# 2018-11-13 04:12:49 (1.53 MB/s) - ‘yolov3.cfg’ saved [211930]

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2018-11-13 04:12:53--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  4.82MB/s    in 48s
#
# 2018-11-13 04:13:40 (4.97 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !git clone https://github.com/allanzelener/YAD2K.git
# Out:
# Cloning into 'YAD2K'...
# remote: Enumerating objects: 243, done.
# remote: Total 243 (delta 0), reused 0 (delta 0), pack-reused 243
# Receiving objects: 100% (243/243), 2.35 MiB | 5.77 MiB/s, done.
# Resolving deltas: 100% (106/106), done.

# %%
cd /content
# Out:
# /content

# %%
# !ls
# Out:
# sample_data  YOLOw-Keras

# %%
cd ..
# Out:
# /

# %%
# !ls
# Out:
# bin	    content  etc   lib64  opt	run   sys    usr
# boot	    datalab  home  media  proc	sbin  tmp    var
# colabtools  dev      lib   mnt	  root	srv   tools

# %%
cd content
# Out:
# /content

# %%
# !ls
# Out:
# sample_data  YOLOw-Keras

# %%
# !git clone https://github.com/qqwweee/keras-yolo3.git
# Out:
# Cloning into 'keras-yolo3'...
# remote: Enumerating objects: 144, done.
# remote: Total 144 (delta 0), reused 0 (delta 0), pack-reused 144
# Receiving objects: 100% (144/144), 149.41 KiB | 1.19 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
cd /content/keras-yolo3
# Out:
# /content/keras-yolo3

# %%
# !cat yolov3.cfg
# Out:
# [net]
# # Testing
# batch=1
# subdivisions=1
# # Training
# # batch=64
# # subdivisions=16
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# ...

# %%
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Traceback (most recent call last):
#   File "convert.py", line 262, in <module>
#     _main(parser.parse_args())
#   File "convert.py", line 73, in _main
#     weights_file = open(weights_path, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'yolov3.weights'

# %%
cd ..
# Out:
# /content

# %%
# !ls
# Out:
# keras-yolo3  sample_data  YOLOw-Keras

# %%
cp -r /content/yolov3.weights /content/keras-yolo3/
# Out:
# cp: cannot stat '/content/yolov3.weights': No such file or directory

# %%
pwd

# %%
cd /content/YAD2K
# Out:
# [Errno 2] No such file or directory: '/content/YAD2K'
# /content/keras-yolo3

# %%
# !python yad2k.py yolov3.cfg yolov3.weights model_data/yolo.h5

# %%
cp -r /content/yolov3.weights /content/YAD2K

# %%
cp -r /content/yolov3.cfg /content/YAD2K

# %%
cd keras-yolo3
# Out:
# /content/keras-yolo3

# %%
# !ls
# Out:
# coco_annotation.py  LICENSE		 voc_annotation.py  yolov3.weights
# convert.py	    model_data		 yolo3		    yolo_video.py
# darknet53.cfg	    README.md		 yolo.py
# font		    train_bottleneck.py  yolov3.cfg
# kmeans.py	    train.py		 yolov3-tiny.cfg

# %%
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Traceback (most recent call last):
#   File "convert.py", line 262, in <module>
#     _main(parser.parse_args())
#   File "convert.py", line 73, in _main
#     weights_file = open(weights_path, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'yolov3.weights'

# %%
pwd

# %%
# !cat convert.py
# Out:
# #! /usr/bin/env python
# """
# Reads Darknet config and weights and creates Keras model with TF backend.
#
# """
#
# import argparse
# import configparser
# import io
# import os
# from collections import defaultdict
#
# import numpy as np
# from keras import backend as K
# from keras.layers import (Conv2D, Input, ZeroPadding2D, Add,
#                           UpSampling2D, MaxPooling2D, Concatenate)
# from keras.layers.advanced_activations import LeakyReLU
# from keras.layers.normalization import BatchNormalization
# from keras.models import Model
# from keras.regularizers import l2
# from keras.utils.vis_utils import plot_model as plot
#
#
# parser = argparse.ArgumentParser(description='Darknet To Keras Converter.')
# parser.add_argument('config_path', help='Path to Darknet cfg file.')
# parser.add_argument('weights_path', help='Path to Darknet weights file.')
# parser.add_argument('output_path', help='Path to output Keras model file.')
# parser.add_argument(
#     '-p',
# ...

# %%
# !python yolo_video.py --image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import PIL
PIL.Image.open("/content/images/1045023827_4ec3e8ba5c_z.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x448 at 0x7F99F3080588>

# %%
# !cp -r /content/keras-yolo3/Mask_RCNN/images /content/

# %%
# !ls /content/images
# Out:
# 1045023827_4ec3e8ba5c_z.jpg  5951960966_d4e1cda5d0_z.jpg
# 12283150_12d37e6389_z.jpg    6584515005_fce9cec486_z.jpg
# 2383514521_1fc8d7b0de_z.jpg  6821351586_59aa0dc110_z.jpg
# 2502287818_41e4b0c4fb_z.jpg  7581246086_cf7bbb7255_z.jpg
# 2516944023_d00345997d_z.jpg  7933423348_c30bd9bd4e_z.jpg
# 25691390_f9944f61b5_z.jpg    8053677163_d4c8f416be_z.jpg
# 262985539_1709e54576_z.jpg   8239308689_efa6c11b08_z.jpg
# 3132016470_c27baa00e8_z.jpg  8433365521_9252889f9a_z.jpg
# 3627527276_6fe8cd9bfe_z.jpg  8512296263_5fc5458e20_z.jpg
# 3651581213_f81963d1dd_z.jpg  8699757338_c3941051b6_z.jpg
# 3800883468_12af3c0b50_z.jpg  8734543718_37f6b8bd45_z.jpg
# 3862500489_6fd195d183_z.jpg  8829708882_48f263491e_z.jpg
# 3878153025_8fde829928_z.jpg  9118579087_f9ffa19e63_z.jpg
# 4410436637_7b0ca36ee7_z.jpg  9247489789_132c0d534a_z.jpg
# 4782628554_668bc31826_z.jpg

# %%
import time
toc1 = time.time()
# !python yolo_video.py --image
tic1 = time.time()
print("Time is",(tic1-toc1)*1000,"ms")
# Out:
# Using TensorFlow backend.
# Image detection mode
#  Ignoring remaining command line arguments: ./path2your_video,
# model_data/yolo.h5 model, anchors, and classes loaded.
# Input image filename:/content/images/1045023827_4ec3e8ba5c_z.jpg
# (416, 416, 3)
# Found 11 boxes for img
# fire hydrant 0.98 (310, 274) (395, 381)
# truck 0.78 (418, 152) (626, 267)
# car 0.49 (387, 217) (436, 271)
# car 0.55 (418, 152) (626, 267)
# person 0.35 (131, 70) (174, 150)
# person 0.53 (126, 65) (183, 372)
# person 0.99 (302, 97) (400, 323)
# person 1.00 (140, 86) (235, 383)
# person 1.00 (457, 58) (556, 403)
# person 1.00 (219, 95) (281, 388)
# person 1.00 (25, 33) (156, 403)
# 5.059929591000582
# Input image filename:Traceback (most recent call last):
#   File "yolo_video.py", line 73, in <module>
#     detect_img(YOLO(**vars(FLAGS)))
#   File "yolo_video.py", line 8, in detect_img
#     img = input('Input image filename:')
# KeyboardInterrupt
# ^C
# Time is 63785.789489746094 ms

# %%
import time
toc1 = time.time()
# !python yolo_video.py --image
tic1 = time.time()
print("Time is",(tic1-toc1)*10,"ms")
# Out:
# Using TensorFlow backend.
# Image detection mode
#  Ignoring remaining command line arguments: ./path2your_video,
# Traceback (most recent call last):
#   File "/content/keras-yolo3/keras-yolo3/yolo.py", line 70, in generate
#     self.yolo_model = load_model(model_path, compile=False)
#   File "/usr/local/lib/python3.6/dist-packages/keras/models.py", line 260, in load_model
#     f = h5py.File(filepath, mode='r')
#   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py", line 312, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py", line 142, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 78, in h5py.h5f.open
# ...

# %%
# !git clone https://github.com/matterport/Mask_RCNN
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 914 (delta 0), reused 0 (delta 0), pack-reused 913
# Receiving objects: 100% (914/914), 113.30 MiB | 40.95 MiB/s, done.
# Resolving deltas: 100% (540/540), done.

# %%
# !git clone https://github.com/matterport/Mask_RCNN
# Out:
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.

# %%
# !ls /content/keras-yolo3/Mask_RCNN/images
# Out:
# ls: cannot access '/content/keras-yolo3/Mask_RCNN/images': No such file or directory

# %%
cd /content/keras-yolo3/Mask_RCNN/images
# Out:
# [Errno 2] No such file or directory: '/content/keras-yolo3/Mask_RCNN/images'
# /content/keras-yolo3/keras-yolo3

# %%
import PIL
import time
toc1 = time.time()
# !python yolo_video.py --image
tic1 = time.time()
PIL.Image.open("/content/keras-yolo3/Mask_RCNN/images/1045023827_4ec3e8ba5c_z.jpg")
print("Time is",(tic1-toc1)*10,"ms")
# Out:
# Using TensorFlow backend.
# Image detection mode
#  Ignoring remaining command line arguments: ./path2your_video,
# model_data/yolo.h5 model, anchors, and classes loaded.
# Input image filename:/content/keras-yolo3/Mask_RCNN/images/1045023827_4ec3e8ba5c_z.jpg
# (416, 416, 3)
# Found 11 boxes for img
# fire hydrant 0.98 (310, 274) (395, 381)
# truck 0.78 (418, 152) (626, 267)
# car 0.49 (387, 217) (436, 271)
# car 0.55 (418, 152) (626, 267)
# person 0.35 (131, 70) (174, 150)
# person 0.53 (126, 65) (183, 372)
# person 0.99 (302, 97) (400, 323)
# person 1.00 (140, 86) (235, 383)
# person 1.00 (457, 58) (556, 403)
# person 1.00 (219, 95) (281, 388)
# person 1.00 (25, 33) (156, 403)
# 4.06064372700007
# Input image filename:Traceback (most recent call last):
#   File "yolo_video.py", line 73, in <module>
#     detect_img(YOLO(**vars(FLAGS)))
#   File "yolo_video.py", line 8, in detect_img
#     img = input('Input image filename:')
# KeyboardInterrupt
# ^C
# Time is 371.15883111953735 ms

# %%
# !python yolo_video.py --image
# Out:
# Using TensorFlow backend.
# Image detection mode
#  Ignoring remaining command line arguments: ./path2your_video,
# model_data/yolo.h5 model, anchors, and classes loaded.
# Input image filename:/content/keras-yolo3/Mask_RCNN/images/1045023827_4ec3e8ba5c_z.jpg
# (416, 416, 3)
# Found 11 boxes for img
# fire hydrant 0.98 (310, 274) (395, 381)
# truck 0.78 (418, 152) (626, 267)
# car 0.49 (387, 217) (436, 271)
# car 0.55 (418, 152) (626, 267)
# person 0.35 (131, 70) (174, 150)
# person 0.53 (126, 65) (183, 372)
# person 0.99 (302, 97) (400, 323)
# person 1.00 (140, 86) (235, 383)
# person 1.00 (457, 58) (556, 403)
# person 1.00 (219, 95) (281, 388)
# person 1.00 (25, 33) (156, 403)
# 5.125185311999985
# Input image filename:Traceback (most recent call last):
#   File "yolo_video.py", line 73, in <module>
#   File "yolo_video.py", line 8, in detect_img
#     img = input('Input image filename:')
# KeyboardInterrupt
